# %% [markdown]
# # Hate Speech Detection with CNN

# %%
# !pip install tensorflow-cpu==2.15.0 pandas scikit-learn matplotlib --quiet

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dropout, Dense
import matplotlib.pyplot as plt
import pickle

# %%
# Load dataset
df = pd.read_csv('hate_speech_data.csv')
df.dropna(subset=['text', 'label'], inplace=True)
df.head()
# Out:
#                 text  label
# 0         I hate you      1
# 1  You are beautiful      0
# 2   This is terrible      1
# 3       You are kind      0
# 4  Shut up and leave      1

# %%
# Preprocessing
vocab_size = 10000
max_len = 100
embedding_dim = 100

tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df['text'])
sequences = tokenizer.texts_to_sequences(df['text'])
padded = pad_sequences(sequences, maxlen=max_len, padding='post')
labels = np.array(df['label'])
X_train, X_test, y_train, y_test = train_test_split(padded, labels, test_size=0.2, random_state=42)

# %%
# Model definition and training
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_len),
    Conv1D(128, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 936ms/step - loss: 0.6960 - accuracy: 0.7500 - val_loss: 0.6961 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6898 - accuracy: 0.5000 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 3/5
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6789 - accuracy: 0.7500 - val_loss: 0.6976 - val_accuracy: 0.5000
# Epoch 4/5
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6605 - accuracy: 0.5000 - val_loss: 0.6983 - val_accuracy: 0.5000
# Epoch 5/5
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6745 - accuracy: 0.7500 - val_loss: 0.6994 - val_accuracy: 0.5000

# %%
# Plot training graphs
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
